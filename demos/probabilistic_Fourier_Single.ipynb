# %% [markdown]
# # Demo - Probabilistic Fourier (single sample)

# %% [markdown]
# This file provides an demo of the probabilistic Fourier framework as outline in "Bayesian spectrum estimation of unevenly sampled data" - Qi et al.

# %% [markdown]
# $$ {\bf{s}}_t = {\bf{s}}_{t-1} + {\bf{w}}_t $$
# $$ {\bf{y}}_t = C^\top {\bf{s}}_t + {\bf{v}}_t $$
#
# The single sample approach is used to prevent error relating to the positive definiteness of the covariance matrices.

# %% [markdown]
# ## Load packages and functions

# %%
using ForneyLab       # based on last official release
using LinearAlgebra
using Plots
using PyPlot
using ProgressMeter
using Compat
using WAV
using Base64
using FileIO
using HDF5
using FLAC
using DSP
using FFTW

include("../functions/auxiliary/buffer.jl")
include("../functions/auxiliary/audioplayer.jl")
include("../functions/auxiliary/workflow.jl")
include("../functions/auxiliary/fourier.jl")
;

# %% [markdown]
# ## Settings

# %%
# data loading
sound_file = "../data/obama.wav"   # specify sound location
fs_desired = 8000                 # specify desired sampling frequency

# input buffer parameters
step_size = 1                     # specify step size of buffer
buffer_size = 1                   # specify size of buffer

# probabilistic fourier parameters 
σ_observation = 0.1                # specify observation noise std
σ_process = 1e3                    # specify process noise std
freq_bins = 15
freq = collect(fs_desired/(2*(freq_bins+1)):fs_desired/(2*(freq_bins+1)):(fs_desired/2-fs_desired/(2*(freq_bins+1))))
;

# %% [markdown]
# ## Load data

# %%
# load and process speech signal
x_time, fs_time = wavread(sound_file, format="native")
fs_time = Int(fs_time)
x_time = x_time[24*fs_time+1:27*fs_time]
x_time = resample(x_time, fs_desired/fs_time)
x_time = 100*x_time/var(x_time)

# specify time axis
t = collect((1:length(x_time))/fs_desired)

# create audioplayer
audioplayers(x_time, fs=fs_desired)
;
# Out:
# <div><audio controls="controls" {autoplay}>
# <source src="data:audio/wav;base64,..." type="audio/wav" />
# Your browser does not support the audio element.
# </audio></div>

# %% [markdown]
# ## Visualize data

# %%
# create figure with subplots
_, ax = plt.subplots(ncols=2, figsize=(15,5))

# plot speech signal as a function of time
ax[1].plot(t, x_time)

# plot spectrogram of speech signal
plot_spectrogram(spectrogram(x_time, 32, 0, fs=fs_desired), fs_desired, ax=ax[2])

# visual modifications
ax[1].grid(), ax[1].set_ylabel("x[t]"), ax[1].set_xlabel("time [sec]"), ax[1].set_title("speech signal"), ax[2].set_title("spectrogram")
;
# Out:
# Figure(PyObject <Figure size 1500x500 with 2 Axes>)

# %% [markdown]
# ## Specify generative model

# %%
# create factor graph
fg = FactorGraph()

# specify process noise
@RV w ~ GaussianMeanVariance(zeros(2*length(freq)), σ_process^2*Ic(2*length(freq)))

# specify observation noise
@RV v ~ GaussianMeanVariance(zeros(buffer_size), σ_observation^2*Ic(buffer_size))

# specify previous hidden state (spectral components)
@RV s_min ~ GaussianMeanVariance(placeholder(:μ_s_min, dims = (2*length(freq),)),
                                 placeholder(:Σ_s_min, dims = (2*length(freq), 2*length(freq))))

# specify new hidden state
@RV s = s_min + w

# specify Fourier matrix
@RV C

# specify observations
@RV x = C*s
@RV y = x + v

# create placeholder for fourier matrix
placeholder(C, :C, dims = (buffer_size, 2*length(freq)))

# create placeholder for observations
placeholder(y, :y, dims = (buffer_size,))

# draw factor graph
ForneyLab.draw(fg)
# ForneyLab.draw(fg, external_viewer=:default)
;
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="681pt" height="629pt"
#  viewBox="0.00 0.00 681.00 629.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 625)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-625 677,-625 677,4 -4,4"/>
# <!-- 6880102501800263527 -->
# <g id="node1" class="node"><title>6880102501800263527</title>
# <polygon fill="none" stroke="black" points="505,-522 433,-522 433,-450 505,-450 505,-522"/>
# <text text-anchor="middle" x="469" y="-488.8" font-family="Times New Roman,serif" font-size="9.00">+</text>
# <text text-anchor="middle" x="469" y="-478.8" font-family="Times New Roman,serif" font-size="9.00">addition_2</text>
# </g>
# <!-- 7363097582376646986 -->
# <g id="node7" class="node"><title>7363097582376646986</title>
# <polygon fill="none" stroke="black" points="554,-405 450,-405 450,-333 554,-333 554,-405"/>
# <text text-anchor="middle" x="502" y="-371.8" font-family="Times New Roman,serif" font-size="9.00">𝒩</text>
# <text text-anchor="middle" x="502" y="-361.8" font-family="Times New Roman,serif" font-size="9.00">gaussianmeanvariance_2</text>
# </g>
# <!-- 6880102501800263527&#45;&#45;7363097582376646986 -->
# <g id="edge9" class="edge"><title>6880102501800263527&#45;&#45;7363097582376646986</title>
# <path fill="none" stroke="black" d="M479.08,-449.871C483.137,-435.736 487.806,-419.463 491.868,-405.31"/>
# <text text-anchor="start" x="487" y="-425.6" font-family="Times New Roman,serif" font-size="8.00" fill="red">v</text>
# <text text-anchor="start" x="470.868" y="-407.91" font-family="Times New Roman,serif" font-size="8.00">1 out </text>
# <text text-anchor="start" x="458.08" y="-443.471" font-family="Times New Roman,serif" font-size="8.00">3 in2 </text>
# </g>
# <!-- 6493981505738080939 -->
# <g id="node10" class="node"><title>6493981505738080939</title>
# <polygon fill="none" stroke="black" points="312,-405 236,-405 236,-333 312,-333 312,-405"/>
# <text text-anchor="middle" x="274" y="-371.8" font-family="Times New Roman,serif" font-size="9.00">×</text>
# <text text-anchor="middle" x="274" y="-361.8" font-family="Times New Roman,serif" font-size="9.00">multiplication_1</text>
# </g>
# <!-- 6880102501800263527&#45;&#45;6493981505738080939 -->
# <g id="edge10" class="edge"><title>6880102501800263527&#45;&#45;6493981505738080939</title>
# <path fill="none" stroke="black" d="M432.779,-463.639C398.415,-443.373 346.971,-413.034 312.025,-392.425"/>
# <text text-anchor="start" x="378" y="-425.6" font-family="Times New Roman,serif" font-size="8.00" fill="red">x</text>
# <text text-anchor="start" x="312.025" y="-395.025" font-family="Times New Roman,serif" font-size="8.00">1 out </text>
# <text text-anchor="start" x="411.779" y="-466.239" font-family="Times New Roman,serif" font-size="8.00">2 in1 </text>
# </g>
# <!-- 471923609257751664 -->
# <g id="node2" class="node"><title>471923609257751664</title>
# <polygon fill="lightgrey" stroke="black" points="503,-621 435,-621 435,-567 503,-567 503,-621"/>
# <text text-anchor="middle" x="469" y="-591.8" font-family="Times New Roman,serif" font-size="9.00">placeholder_y</text>
# </g>
# <!-- 471923609257751664&#45;&#45;6880102501800263527 -->
# <g id="edge6" class="edge"><title>471923609257751664&#45;&#45;6880102501800263527</title>
# <path fill="none" stroke="black" d="M469,-566.798C469,-553.31 469,-536.68 469,-522.099"/>
# <text text-anchor="start" x="469" y="-542.6" font-family="Times New Roman,serif" font-size="8.00" fill="red">y</text>
# <text text-anchor="start" x="448" y="-524.699" font-family="Times New Roman,serif" font-size="8.00">1 out </text>
# <text text-anchor="start" x="448" y="-560.398" font-family="Times New Roman,serif" font-size="8.00">1 out </text>
# </g>
# <!-- 13469430208390742312 -->
# <g id="node3" class="node"><title>13469430208390742312</title>
# <polygon fill="lightgrey" stroke="black" points="54,-54 0,-54 0,-0 54,-0 54,-54"/>
# <text text-anchor="middle" x="27" y="-24.8" font-family="Times New Roman,serif" font-size="9.00">clamp_2</text>
# </g>
# <!-- 2795198699960973453 -->
# <g id="node4" class="node"><title>2795198699960973453</title>
# <polygon fill="lightgrey" stroke="black" points="285,-513 217,-513 217,-459 285,-459 285,-513"/>
# <text text-anchor="middle" x="251" y="-483.8" font-family="Times New Roman,serif" font-size="9.00">placeholder_C</text>
# </g>
# <!-- 2795198699960973453&#45;&#45;6493981505738080939 -->
# <g id="edge11" class="edge"><title>2795198699960973453&#45;&#45;6493981505738080939</title>
# <path fill="none" stroke="black" d="M251.07,-458.841C251.515,-447.699 252.593,-434.618 255,-423 256.21,-417.161 257.922,-411.096 259.828,-405.243"/>
# <text text-anchor="start" x="255" y="-425.6" font-family="Times New Roman,serif" font-size="8.00" fill="red">C</text>
# <text text-anchor="start" x="246.828" y="-407.843" font-family="Times New Roman,serif" font-size="8.00">3 a </text>
# <text text-anchor="start" x="230.07" y="-452.441" font-family="Times New Roman,serif" font-size="8.00">1 out </text>
# </g>
# <!-- 6736633184126974824 -->
# <g id="node5" class="node"><title>6736633184126974824</title>
# <polygon fill="lightgrey" stroke="black" points="439,-54 345,-54 345,-0 439,-0 439,-54"/>
# <text text-anchor="middle" x="392" y="-24.8" font-family="Times New Roman,serif" font-size="9.00">placeholder_Σ_s_min</text>
# </g>
# <!-- 9987920048586385234 -->
# <g id="node6" class="node"><title>9987920048586385234</title>
# <polygon fill="none" stroke="black" points="240,-171 136,-171 136,-99 240,-99 240,-171"/>
# <text text-anchor="middle" x="188" y="-137.8" font-family="Times New Roman,serif" font-size="9.00">𝒩</text>
# <text text-anchor="middle" x="188" y="-127.8" font-family="Times New Roman,serif" font-size="9.00">gaussianmeanvariance_1</text>
# </g>
# <!-- 9987920048586385234&#45;&#45;13469430208390742312 -->
# <g id="edge5" class="edge"><title>9987920048586385234&#45;&#45;13469430208390742312</title>
# <path fill="none" stroke="black" d="M135.728,-99.5848C108.55,-81.6911 76.4563,-60.5613 54.2147,-45.9177"/>
# <text text-anchor="start" x="108" y="-74.6" font-family="Times New Roman,serif" font-size="8.00" fill="red">clamp_2</text>
# <text text-anchor="start" x="54.2147" y="-48.5177" font-family="Times New Roman,serif" font-size="8.00">1 out </text>
# <text text-anchor="start" x="121.728" y="-102.185" font-family="Times New Roman,serif" font-size="8.00">3 v </text>
# </g>
# <!-- 11561347093838252585 -->
# <g id="node9" class="node"><title>11561347093838252585</title>
# <polygon fill="lightgrey" stroke="black" points="223,-54 169,-54 169,-0 223,-0 223,-54"/>
# <text text-anchor="middle" x="196" y="-24.8" font-family="Times New Roman,serif" font-size="9.00">clamp_1</text>
# </g>
# <!-- 9987920048586385234&#45;&#45;11561347093838252585 -->
# <g id="edge4" class="edge"><title>9987920048586385234&#45;&#45;11561347093838252585</title>
# <path fill="none" stroke="black" d="M190.642,-98.9979C191.743,-84.4044 193,-67.7451 194.02,-54.2331"/>
# <text text-anchor="start" x="193" y="-74.6" font-family="Times New Roman,serif" font-size="8.00" fill="red">clamp_1</text>
# <text text-anchor="start" x="173.02" y="-56.8331" font-family="Times New Roman,serif" font-size="8.00">1 out </text>
# <text text-anchor="start" x="174.642" y="-92.5979" font-family="Times New Roman,serif" font-size="8.00">2 m </text>
# </g>
# <!-- 12725594290303981101 -->
# <g id="node12" class="node"><title>12725594290303981101</title>
# <polygon fill="lightgrey" stroke="black" points="504,-279 450,-279 450,-225 504,-225 504,-279"/>
# <text text-anchor="middle" x="477" y="-249.8" font-family="Times New Roman,serif" font-size="9.00">clamp_3</text>
# </g>
# <!-- 7363097582376646986&#45;&#45;12725594290303981101 -->
# <g id="edge1" class="edge"><title>7363097582376646986&#45;&#45;12725594290303981101</title>
# <path fill="none" stroke="black" d="M478.869,-332.86

# %%
# create algorithm
algo = compatibility_fix(sumProductAlgorithm([s, x]))

# evaluate algorithm
eval(Meta.parse(algo))
# println(algo)
;

# %% [markdown]
# ## Perform inference

# %%
messages=Array{Message}(undef, 7)
data = Dict()
marginals = Dict()

# set priors 
μ_s_min = zeros(2*length(freq))
Σ_s_min = 1e6*Ic(2*length(freq)) 

# initialize buffer
buf = BufferData(x_time, t, buffer_size)

# initialize placeholder for hidden states and observation
μ_x = Array{Float64,1}[]
Σ_x = Array{Float64,2}[]
μ_s = Array{Float64,1}[]
Σ_s = Array{Float64,2}[]

# create progress bar
p = Progress(len(buf, step_size), 1, "Observed ")

# loop through samples
for k = 1:len(buf, step_size)
        
    # update progress bar
    update!(p, k)
    
    # fill data dictionary
    data[:μ_s_min] = μ_s_min
    data[:Σ_s_min] = Σ_s_min
    data[:y] = buf.buffer_s
    data[:C] = calc_C(freq, buf.buffer_t)*sqrt(32)
    
    # infer parameters
    marginals = step!(data, marginals, messages)

    # estimate prediction of x
    push!(μ_x, ForneyLab.unsafeMean(messages[7].dist))
    push!(Σ_x, ForneyLab.unsafeCov(messages[7].dist))
    
    # save marginal of s
    push!(μ_s, ForneyLab.unsafeMean(marginals[:s]))
    push!(Σ_s, ForneyLab.unsafeCov(marginals[:s]))
    
    # update hidden states
    μ_s_min = ForneyLab.unsafeMean(marginals[:s])
    Σ_s_min = ForneyLab.unsafeCov(marginals[:s]) 
    
    # update buffer
    FLAG_data_remaining = step!(buf, step_size)
    
end
# Out:
# Observed 100%|██████████████████████████████████████████| Time: 0:00:25:00

# %%
# convert μ_x to a 1d array
μ_x_pred = expand(reverse(hcat(μ_x...),dims=1))

# convert s_x to a 2d array
if length(size(μ_s)) != 2
    μ_s = hcat(μ_s...)
end

# calculate magnitude spectrum
mag_μ_s = log10.((μ_s[1:length(freq),:].^2 + μ_s[length(freq)+1:end,:].^2))


# create figure with subplots
fig, ax = plt.subplots(ncols=2, figsize=(15,5))

# plot speech signal as a function of time
cmp = ax[1].imshow(mag_μ_s,
                   aspect="auto",
                   cmap="jet",
                   origin="lower",
                   extent=[minimum(t), maximum(t), minimum(freq), maximum(freq)])
fig.colorbar(cmp, ax=ax[1])

# plot spectrogram of speech signal
plot_spectrogram(spectrogram(x_time, 32, 0, fs=fs_desired), fs_desired, ax=ax[2], colorbar=true)

# change visuals
ax[1].set_xlim(minimum(t), maximum(t)), ax[1].set_ylim(minimum(freq), maximum(freq)), ax[2].set_ylim(minimum(freq), maximum(freq)), ax[1].set_xlabel("time [sec]"), ax[1].set_ylabel("frequency [Hz]"), ax[1].set_title("Predicted spectrum"), ax[2].set_title("STFT spectrum")
;
# Out:
# Figure(PyObject <Figure size 1500x500 with 4 Axes>)

# %%
# create figure with subplots
fig, ax = plt.subplots(ncols=2, figsize=(15,5))

# plot actual, noisy and marginal of frequency component
ax[1].plot(t, x_time, label="true"), ax[1].plot(t[1:length(μ_x_pred)], μ_x_pred, label="prediction")
ax[2].plot(t, x_time, label="true"), ax[2].plot(t[1:length(μ_x_pred)], μ_x_pred, label="prediction")

# change vizualization
ax[1].grid(), ax[1].set_xlim(0,3), ax[1].set_ylim(-2.5, 2.5), ax[1].set_xlabel("time [sec]"), ax[1].set_ylabel("x[t]"), ax[1].legend()
ax[2].grid(), ax[2].set_xlim(0.55,0.56), ax[2].set_ylim(-1, 1), ax[2].set_xlabel("time [sec]"), ax[2].set_ylabel("x[t]"), ax[2].legend()

# create audioplayers
audioplayers(x_time, μ_x_pred, fs=fs_desired)
;
# Out:
# <div><audio controls="controls" {autoplay}>
# <source src="data:audio/wav;base64,..." type="audio/wav" />
# Your browser does not support the audio element.
# </audio><audio controls="controls" {autoplay}>
# <source src="data:audio/wav;base64,..." type="audio/wav" />
# Your browser does not support the audio element.
# </audio></div>
# Figure(PyObject <Figure size 1500x500 with 2 Axes>)

# %% [markdown]
# ## Performance metrics

# %%
MSE = 1/length(μ_x_pred) * sum(abs.(μ_x_pred - x_time[1:length(μ_x_pred)]).^2)
# Out:
# 0.05979158731966668

# %%
MAE = 1/length(μ_x_pred) * sum(μ_x_pred - x_time[1:length(μ_x_pred)])
# Out:
# 0.008272338358436057

# %%
using Distributions;
logBME = Float64[]
# initialize buffer
buf = BufferData(x_time, t, buffer_size)
for k = 1:length(μ_x)
    try 
        push!(logBME, logpdf(Distributions.Normal(μ_x[k][1], Σ_x[k][1,1]), buf.buffer_s[1]))
    catch
    end
    step!(buf, step_size)
end
print("nr: "* string(length(logBME))* "       mean:"* string(mean(logBME)))
# Out:
# nr: 23999       mean:-24.277455475123325
# WARNING: using Distributions.Multivariate in module Main conflicts with an existing identifier.
