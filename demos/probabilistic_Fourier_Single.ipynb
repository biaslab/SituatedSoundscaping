# %% [markdown]
# # Demo - Probabilistic Fourier (single sample)

# %% [markdown]
# This file provides an demo of the probabilistic Fourier framework as outline in "Bayesian spectrum estimation of unevenly sampled data" - Qi et al.

# %% [markdown]
# $$ {\bf{s}}_t = {\bf{s}}_{t-1} + {\bf{w}}_t $$
# $$ {\bf{y}}_t = C^\top {\bf{s}}_t + {\bf{v}}_t $$
#
# The single sample approach is used to prevent error relating to the positive definiteness of the covariance matrices.

# %% [markdown]
# ## Load packages and functions

# %%
using ForneyLab       # based on last official release
using LinearAlgebra
using Plots
using PyPlot
using ProgressMeter
using Compat
using WAV
using Base64
using FileIO
using HDF5
using FLAC
using DSP
using FFTW

include("../functions/auxiliary/buffer.jl")
include("../functions/auxiliary/audioplayer.jl")
include("../functions/auxiliary/workflow.jl")
include("../functions/auxiliary/fourier.jl")
;

# %% [markdown]
# ## Settings

# %%
# data loading
sound_file = "../data/obama.wav"   # specify sound location
fs_desired = 8000                 # specify desired sampling frequency

# input buffer parameters
step_size = 1                     # specify step size of buffer
buffer_size = 1                   # specify size of buffer

# probabilistic fourier parameters 
σ_observation = 0.1                # specify observation noise std
σ_process = 1e2                    # specify process noise std
freq_bins = 15
freq = collect(fs_desired/(2*(freq_bins+1)):fs_desired/(2*(freq_bins+1)):(fs_desired/2-fs_desired/(2*(freq_bins+1))))
;

# %% [markdown]
# ## Load data

# %%
# load and process speech signal
x_time, fs_time = wavread(sound_file, format="native")
fs_time = Int(fs_time)
x_time = x_time[24*fs_time+1:27*fs_time]
x_time = resample(x_time, fs_desired/fs_time)
x_time = 100*x_time/var(x_time)

# specify time axis
t = collect((1:length(x_time))/fs_desired)

# create audioplayer
audioplayers(x_time, fs=fs_desired)
;
# Out:
# <div><audio controls="controls" {autoplay}>
# <source src="data:audio/wav;base64,..." type="audio/wav" />
# Your browser does not support the audio element.
# </audio></div>

# %% [markdown]
# ## Visualize data

# %%
# create figure with subplots
_, ax = plt.subplots(ncols=2, figsize=(15,5))

# plot speech signal as a function of time
ax[1].plot(t, x_time)

# plot spectrogram of speech signal
plot_spectrogram(spectrogram(x_time, 32, 0, fs=fs_desired), fs_desired, ax=ax[2])

# visual modifications
ax[1].grid(), ax[1].set_ylabel("x[t]"), ax[1].set_xlabel("time [sec]"), ax[1].set_title("speech signal"), ax[2].set_title("spectrogram")
;
# Out:
# Figure(PyObject <Figure size 1500x500 with 2 Axes>)

# %% [markdown]
# ## Specify generative model

# %%
# create factor graph
fg = FactorGraph()

# specify process noise
@RV w ~ GaussianMeanVariance(zeros(2*length(freq)), σ_process^2*Ic(2*length(freq)))

# specify previous hidden state (spectral components)
@RV s_min ~ GaussianMeanVariance(placeholder(:μ_s_min, dims = (2*length(freq),)),
                                 placeholder(:Σ_s_min, dims = (2*length(freq), 2*length(freq))))

# specify new hidden state
@RV s = s_min + w

# specify Fourier matrix
@RV C

# specify observations
@RV x = C*s
@RV y ~ GaussianMeanVariance(x, σ_observation^2*Ic(buffer_size))

# create placeholder for fourier matrix
placeholder(C, :C, dims = (buffer_size, 2*length(freq)))

# create placeholder for observations
placeholder(y, :y, dims = (buffer_size,))

# draw factor graph
ForneyLab.draw(fg)
# ForneyLab.draw(fg, external_viewer=:default)
;
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="656pt" height="629pt"
#  viewBox="0.00 0.00 655.50 629.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 625)">
# <title>G</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-625 651.5,-625 651.5,4 -4,4"/>
# <!-- 15130130087276785199 -->
# <g id="node1" class="node"><title>15130130087276785199</title>
# <polygon fill="none" stroke="black" points="579.5,-522 475.5,-522 475.5,-450 579.5,-450 579.5,-522"/>
# <text text-anchor="middle" x="527.5" y="-488.8" font-family="Times New Roman,serif" font-size="9.00">𝒩</text>
# <text text-anchor="middle" x="527.5" y="-478.8" font-family="Times New Roman,serif" font-size="9.00">gaussianmeanvariance_3</text>
# </g>
# <!-- 11398951824959749499 -->
# <g id="node4" class="node"><title>11398951824959749499</title>
# <polygon fill="none" stroke="black" points="375.5,-405 299.5,-405 299.5,-333 375.5,-333 375.5,-405"/>
# <text text-anchor="middle" x="337.5" y="-371.8" font-family="Times New Roman,serif" font-size="9.00">×</text>
# <text text-anchor="middle" x="337.5" y="-361.8" font-family="Times New Roman,serif" font-size="9.00">multiplication_1</text>
# </g>
# <!-- 15130130087276785199&#45;&#45;11398951824959749499 -->
# <g id="edge3" class="edge"><title>15130130087276785199&#45;&#45;11398951824959749499</title>
# <path fill="none" stroke="black" d="M475.33,-453.424C443.801,-434.34 404.311,-410.438 375.692,-393.116"/>
# <text text-anchor="start" x="438.5" y="-425.6" font-family="Times New Roman,serif" font-size="8.00" fill="red">x</text>
# <text text-anchor="start" x="375.692" y="-395.716" font-family="Times New Roman,serif" font-size="8.00">1 out </text>
# <text text-anchor="start" x="459.33" y="-456.024" font-family="Times New Roman,serif" font-size="8.00">2 m </text>
# </g>
# <!-- 7804309031130331205 -->
# <g id="node7" class="node"><title>7804309031130331205</title>
# <polygon fill="lightgrey" stroke="black" points="579.5,-396 525.5,-396 525.5,-342 579.5,-342 579.5,-396"/>
# <text text-anchor="middle" x="552.5" y="-366.8" font-family="Times New Roman,serif" font-size="9.00">clamp_3</text>
# </g>
# <!-- 15130130087276785199&#45;&#45;7804309031130331205 -->
# <g id="edge4" class="edge"><title>15130130087276785199&#45;&#45;7804309031130331205</title>
# <path fill="none" stroke="black" d="M535.137,-449.871C538.899,-432.565 543.357,-412.056 546.814,-396.154"/>
# <text text-anchor="start" x="541.5" y="-425.6" font-family="Times New Roman,serif" font-size="8.00" fill="red">clamp_3</text>
# <text text-anchor="start" x="525.814" y="-398.754" font-family="Times New Roman,serif" font-size="8.00">1 out </text>
# <text text-anchor="start" x="521.137" y="-443.471" font-family="Times New Roman,serif" font-size="8.00">3 v </text>
# </g>
# <!-- 17637111082848251010 -->
# <g id="node2" class="node"><title>17637111082848251010</title>
# <polygon fill="none" stroke="black" points="373.5,-288 301.5,-288 301.5,-216 373.5,-216 373.5,-288"/>
# <text text-anchor="middle" x="337.5" y="-254.8" font-family="Times New Roman,serif" font-size="9.00">+</text>
# <text text-anchor="middle" x="337.5" y="-244.8" font-family="Times New Roman,serif" font-size="9.00">addition_1</text>
# </g>
# <!-- 7017253602766864967 -->
# <g id="node3" class="node"><title>7017253602766864967</title>
# <polygon fill="none" stroke="black" points="299.5,-171 195.5,-171 195.5,-99 299.5,-99 299.5,-171"/>
# <text text-anchor="middle" x="247.5" y="-137.8" font-family="Times New Roman,serif" font-size="9.00">𝒩</text>
# <text text-anchor="middle" x="247.5" y="-127.8" font-family="Times New Roman,serif" font-size="9.00">gaussianmeanvariance_2</text>
# </g>
# <!-- 17637111082848251010&#45;&#45;7017253602766864967 -->
# <g id="edge6" class="edge"><title>17637111082848251010&#45;&#45;7017253602766864967</title>
# <path fill="none" stroke="black" d="M301.423,-220.044C294.394,-213.161 287.388,-205.63 281.5,-198 275.2,-189.836 269.374,-180.355 264.388,-171.299"/>
# <text text-anchor="start" x="281.5" y="-191.6" font-family="Times New Roman,serif" font-size="8.00" fill="red">s_min</text>
# <text text-anchor="start" x="243.388" y="-173.899" font-family="Times New Roman,serif" font-size="8.00">1 out </text>
# <text text-anchor="start" x="280.423" y="-222.644" font-family="Times New Roman,serif" font-size="8.00">2 in1 </text>
# </g>
# <!-- 704306214133477011 -->
# <g id="node5" class="node"><title>704306214133477011</title>
# <polygon fill="none" stroke="black" points="518.5,-171 414.5,-171 414.5,-99 518.5,-99 518.5,-171"/>
# <text text-anchor="middle" x="466.5" y="-137.8" font-family="Times New Roman,serif" font-size="9.00">𝒩</text>
# <text text-anchor="middle" x="466.5" y="-127.8" font-family="Times New Roman,serif" font-size="9.00">gaussianmeanvariance_1</text>
# </g>
# <!-- 17637111082848251010&#45;&#45;704306214133477011 -->
# <g id="edge9" class="edge"><title>17637111082848251010&#45;&#45;704306214133477011</title>
# <path fill="none" stroke="black" d="M373.777,-218.66C390.321,-203.912 409.95,-186.413 426.879,-171.321"/>
# <text text-anchor="start" x="406.5" y="-191.6" font-family="Times New Roman,serif" font-size="8.00" fill="red">w</text>
# <text text-anchor="start" x="405.879" y="-173.921" font-family="Times New Roman,serif" font-size="8.00">1 out </text>
# <text text-anchor="start" x="373.777" y="-221.26" font-family="Times New Roman,serif" font-size="8.00">3 in2 </text>
# </g>
# <!-- 6801835121369202582 -->
# <g id="node9" class="node"><title>6801835121369202582</title>
# <polygon fill="lightgrey" stroke="black" points="93,-54 0,-54 0,-0 93,-0 93,-54"/>
# <text text-anchor="middle" x="46.5" y="-24.8" font-family="Times New Roman,serif" font-size="9.00">placeholder_μ_s_min</text>
# </g>
# <!-- 7017253602766864967&#45;&#45;6801835121369202582 -->
# <g id="edge10" class="edge"><title>7017253602766864967&#45;&#45;6801835121369202582</title>
# <path fill="none" stroke="black" d="M195.476,-106.565C163.837,-89.8793 123.77,-68.7492 93.1582,-52.6058"/>
# <text text-anchor="start" x="147.5" y="-74.6" font-family="Times New Roman,serif" font-size="8.00" fill="red">μ_s_min</text>
# <text text-anchor="start" x="93.1582" y="-55.2058" font-family="Times New Roman,serif" font-size="8.00">1 out </text>
# <text text-anchor="start" x="179.476" y="-109.165" font-family="Times New Roman,serif" font-size="8.00">2 m </text>
# </g>
# <!-- 9968756555160580481 -->
# <g id="node10" class="node"><title>9968756555160580481</title>
# <polygon fill="lightgrey" stroke="black" points="302.5,-54 208.5,-54 208.5,-0 302.5,-0 302.5,-54"/>
# <text text-anchor="middle" x="255.5" y="-24.8" font-family="Times New Roman,serif" font-size="9.00">placeholder_Σ_s_min</text>
# </g>
# <!-- 7017253602766864967&#45;&#45;9968756555160580481 -->
# <g id="edge5" class="edge"><title>7017253602766864967&#45;&#45;9968756555160580481</title>
# <path fill="none" stroke="black" d="M250.142,-98.9979C251.243,-84.4044 252.5,-67.7451 253.52,-54.2331"/>
# <text text-anchor="start" x="252.5" y="-74.6" font-family="Times New Roman,serif" font-size="8.00" fill="red">Σ_s_min</text>
# <text text-anchor="start" x="232.52" y="-56.8331" font-family="Times New Roman,serif" font-size="8.00">1 out </text>
# <text text-anchor="start" x="236.142" y="-92.5979" font-family="Times New Roman,serif" font-size="8.00">3 v </text>
# </g>
# <!-- 11398951824959749499&#45;&#45;17637111082848251010 -->
# <g id="edge7" class="edge"><title>11398951824959749499&#45;&#45;17637111082848251010</title>
# <path fill="none" stroke="black" d="M337.5,-332.871C337.5,-318.736 337.5,-302.463 337.5,-288.31"/>
# <text text-anchor="start" x="337.5" y="-308.6" font-family="Times New Roman,serif" font-size="8.00" fill="red">s</text>
# <text text-anchor="start" x="316.5" y="-290.91" font-family="Times New Roman,serif" font-size="8.00">1 out </text>
# <text text-anchor="start" x="316.5" y="-326.471" font-

# %%
# create algorithm
algo = compatibility_fix(sumProductAlgorithm([s, x]))

# evaluate algorithm
eval(Meta.parse(algo))
# println(algo)
;

# %% [markdown]
# ## Perform inference

# %%
messages=Array{Message}(undef, 6)
data = Dict()
marginals = Dict()

# set priors 
μ_s_min = zeros(2*length(freq))
Σ_s_min = 1e2*Ic(2*length(freq)) 

# initialize buffer
buf = BufferData(x_time, t, buffer_size)

# initialize placeholder for hidden states and observation
μ_x = Array{Float64,1}[]
Σ_x = Array{Float64,2}[]
μ_s = Array{Float64,1}[]
Σ_s = Array{Float64,2}[]

# create progress bar
p = Progress(len(buf, step_size), 1, "Observed ")

# loop through samples
for k = 1:len(buf, step_size)
        
    # update progress bar
    update!(p, k)
    
    # fill data dictionary
    data[:μ_s_min] = μ_s_min
    data[:Σ_s_min] = Σ_s_min
    data[:y] = buf.buffer_s
    data[:C] = calc_C(freq, buf.buffer_t)*sqrt(32)
    
    # infer parameters
    marginals = step!(data, marginals, messages)

    # estimate prediction of x
    push!(μ_x, ForneyLab.unsafeMean(messages[6].dist))
    push!(Σ_x, ForneyLab.unsafeCov(messages[6].dist))
    
    # save marginal of s
    push!(μ_s, ForneyLab.unsafeMean(marginals[:s]))
    push!(Σ_s, ForneyLab.unsafeCov(marginals[:s]))
    
    # update hidden states
    μ_s_min = ForneyLab.unsafeMean(marginals[:s])
    Σ_s_min = ForneyLab.unsafeCov(marginals[:s]) 
    
    # update buffer
    FLAG_data_remaining = step!(buf, step_size)
    
end
# Out:
# Observed 100%|██████████████████████████████████████████| Time: 0:00:25m

# %%
# convert μ_x to a 1d array
μ_x_pred = expand(reverse(hcat(μ_x...),dims=1))
μ_x_pred_select = μ_x_pred[1:Int(buffer_size/step_size):end]
# convert s_x to a 2d array
if length(size(μ_s)) != 2
    μ_s = hcat(μ_s...)
end

# calculate magnitude spectrum
mag_μ_s = log10.((μ_s[1:length(freq),:].^2 + μ_s[length(freq)+1:end,:].^2))


# create figure with subplots
fig, ax = plt.subplots(ncols=2, figsize=(15,5))

# plot speech signal as a function of time
cmp = ax[1].imshow(mag_μ_s,
                   aspect="auto",
                   cmap="jet",
                   origin="lower",
                   extent=[minimum(t), maximum(t), minimum(freq), maximum(freq)])
fig.colorbar(cmp, ax=ax[1])

# plot spectrogram of speech signal
plot_spectrogram(spectrogram(x_time, 32, 0, fs=fs_desired), fs_desired, ax=ax[2], colorbar=true)

# change visuals
ax[1].set_xlim(minimum(t), maximum(t)), ax[1].set_ylim(minimum(freq), maximum(freq)), ax[2].set_ylim(minimum(freq), maximum(freq)), ax[1].set_xlabel("time [sec]"), ax[1].set_ylabel("frequency [Hz]"), ax[1].set_title("Predicted spectrum"), ax[2].set_title("STFT spectrum")
;
# Out:
# Figure(PyObject <Figure size 1500x500 with 4 Axes>)

# %%
# create figure with subplots
fig, ax = plt.subplots(ncols=2, figsize=(15,5))

# plot actual, noisy and marginal of frequency component
ax[1].plot(t, x_time, label="true"), ax[1].plot(t[1:length(μ_x_pred_select)], μ_x_pred_select, label="prediction")
ax[2].plot(t, x_time, label="true"), ax[2].plot(t[1:length(μ_x_pred_select)], μ_x_pred_select, label="prediction")

# change vizualization
ax[1].grid(), ax[1].set_xlim(0,3), ax[1].set_ylim(-2.5, 2.5), ax[1].set_xlabel("time [sec]"), ax[1].set_ylabel("x[t]"), ax[1].legend()
ax[2].grid(), ax[2].set_xlim(1.25,1.26), ax[2].set_ylim(-1, 1), ax[2].set_xlabel("time [sec]"), ax[2].set_ylabel("x[t]"), ax[2].legend()

# create audioplayers
audioplayers(x_time, μ_x_pred, fs=fs_desired)
;
# Out:
# <div><audio controls="controls" {autoplay}>
# <source src="data:audio/wav;base64,..." type="audio/wav" />
# Your browser does not support the audio element.
# </audio><audio controls="controls" {autoplay}>
# <source src="data:audio/wav;base64,..." type="audio/wav" />
# Your browser does not support the audio element.
# </audio></div>
# Figure(PyObject <Figure size 1500x500 with 2 Axes>)

# %% [markdown]
# ## Performance metrics

# %%
MSE = 1/length(μ_x_pred_select) * sum(abs.(μ_x_pred_select - x_time[1:length(μ_x_pred_select)]).^2)
# Out:
# 0.059816799917860534

# %%
MAE = 1/length(μ_x_pred_select) * sum(abs.(μ_x_pred_select - x_time[1:length(μ_x_pred_select)]))
# Out:
# 0.1307913010502975

# %%
using Distributions;
logBME = Float64[]
# initialize buffer
buf = BufferData(x_time, t, buffer_size)
for k = 1:length(μ_x)
    try 
        push!(logBME, logpdf(Distributions.Normal(μ_x[k][1], Σ_x[k][1,1]), buf.buffer_s[1]))
    catch
    end
    step!(buf, step_size)
end
print("nr: "* string(length(logBME))* "       mean:"* string(mean(logBME)))
# Out:
# nr: 23999       mean:-19.67241912069449
# WARNING: using Distributions.Multivariate in module Main conflicts with an existing identifier.
